# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data-temp/CN-Reanalysis-daily-2013010300.csv', encoding='utf-8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   province       370 non-null    object
#  1   city           370 non-null    object
#  2   PM2.5(微克每立方米)  370 non-null    float64
#  3   PM10(微克每立方米)   370 non-null    float64
#  4   SO2(微克每立方米)    370 non-null    float64
#  5   NO2(微克每立方米)    370 non-null    float64
#  6   CO(毫克每立方米)     370 non-null    float64
#  7   O3(微克每立方米)     370 non-null    float64
#  8   U(m/s)         370 non-null    float64
#  9   V(m/s)         370 non-null    float64
#  10  TEMP(K)        370 non-null    float64
#  11  RH(%)          370 non-null    float64
#  12  PSFC(Pa)       370 non-null    float64
#  13  lat            370 non-null    float64
#  14  lon            370 non-null    float64
# dtypes: float64(13), object(2)
# memory usage: 43.5+ KB

# %%
df.head(3)
# Out:
#   province city  PM2.5(微克每立方米)  PM10(微克每立方米)  SO2(微克每立方米)  NO2(微克每立方米)  \
# 0      上海市  上海市      35.990000     45.722400    24.510800    30.654400
# 1      云南省  临沧市      24.324259     26.940926     7.508519     2.581389
# 2      云南省  丽江市      19.836742     22.194831     6.295281     3.741798
#
#    CO(毫克每立方米)  O3(微克每立方米)    U(m/s)    V(m/s)     TEMP(K)      RH(%)  \
# 0    1.480000   40.894000  2.773600 -8.366800  273.939200  80.736000
# 1    0.283241   67.475370  0.038611  3.960926  284.684167  83.339815
# 2    0.259213   67.826629  3.511461  4.861910  276.161685  74.087191
#
#         PSFC(Pa)        lat         lon
# 0  103580.144400  31.172800  121.420000
# 1   84104.466852  23.934907   99.685833
# 2   74596.844270  26.959888  100.515393

# %%
df1 = df.groupby(by=['province', 'city']).mean().reset_index()
df1
# Out:
#     province     city  PM2.5(微克每立方米)  PM10(微克每立方米)  SO2(微克每立方米)  NO2(微克每立方米)  \
# 0        上海市      上海市      35.990000     45.722400    24.510800    30.654400
# 1        云南省      临沧市      24.324259     26.940926     7.508519     2.581389
# 2        云南省      丽江市      19.836742     22.194831     6.295281     3.741798
# 3        云南省      保山市      22.492000     25.107647     6.026118     3.264353
# 4        云南省  大理白族自治州      27.516794     30.871145     7.742824     4.158779
# ..       ...      ...            ...           ...          ...          ...
# 365     黑龙江省      绥化市      37.726446     45.463313    19.644157     9.975663
# 366     黑龙江省      鸡西市      17.274158     18.922277     4.961881     8.920198
# 367     黑龙江省      鹤岗市       2.214118      2.684265     1.987206     3.498382
# 368     黑龙江省      黑河市       2.390345      2.779530     1.392069     2.438777
# 369     黑龙江省    齐齐哈尔市      11.140704     12.660000     4.567437     5.123065
#
# ...

# %%
df2 = df.groupby(by='province', as_index=False).mean()
df2
# Out:
#     province  PM2.5(微克每立方米)  PM10(微克每立方米)  SO2(微克每立方米)  NO2(微克每立方米)  \
# 0        上海市      35.990000     45.722400    24.510800    30.654400
# 1        云南省      41.952840     47.633182    13.872957     7.331031
# 2     内蒙古自治区      13.695022     18.393916    24.134165     9.686645
# 3        北京市      26.388889     39.869167    27.502639    20.072222
# 4        台湾省      15.254430     23.593418     4.898924    11.317342
# 5        吉林省      27.381596     34.606974    13.705197    14.422528
# 6        四川省      55.208922     68.046547    19.909932    15.542831
# 7        天津市      30.577692     55.218654    40.951346    29.295962
# 8    宁夏回族自治区      35.404521     49.702463    65.146365    17.700266
# 9        安徽省      42.991225     59.167216    42.928912    24.256305
# 10       山东省      48.691770     74.612940    58.745217    38.810043
# 11       山西省      39.534820     55.026875    51.535330    22.219250
# 12       广东省      46.393566     61.579931    18.499645    26.138666
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   province       370 non-null    object
#  1   city           370 non-null    object
#  2   PM2.5(微克每立方米)  370 non-null    float64
#  3   PM10(微克每立方米)   370 non-null    float64
#  4   SO2(微克每立方米)    370 non-null    float64
#  5   NO2(微克每立方米)    370 non-null    float64
#  6   CO(毫克每立方米)     370 non-null    float64
#  7   O3(微克每立方米)     370 non-null    float64
#  8   U(m/s)         370 non-null    float64
#  9   V(m/s)         370 non-null    float64
#  10  TEMP(K)        370 non-null    float64
#  11  RH(%)          370 non-null    float64
#  12  PSFC(Pa)       370 non-null    float64
#  13  lat            370 non-null    float64
#  14  lon            370 non-null    float64
# dtypes: float64(13), object(2)
# memory usage: 43.5+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   province       33 non-null     object
#  1   PM2.5(微克每立方米)  33 non-null     float64
#  2   PM10(微克每立方米)   33 non-null     float64
#  3   SO2(微克每立方米)    33 non-null     float64
#  4   NO2(微克每立方米)    33 non-null     float64
#  5   CO(毫克每立方米)     33 non-null     float64
#  6   O3(微克每立方米)     33 non-null     float64
#  7   U(m/s)         33 non-null     float64
#  8   V(m/s)         33 non-null     float64
#  9   TEMP(K)        33 non-null     float64
#  10  RH(%)          33 non-null     float64
#  11  PSFC(Pa)       33 non-null     float64
#  12  lat            33 non-null     float64
#  13  lon            33 non-null     float64
# dtypes: float64(13), object(1)
# memory usage: 3.7+ KB

# %%
df3 = df1.merge(df2, on='province')
df3
# Out:
#     province     city  PM2.5(微克每立方米)_x  PM10(微克每立方米)_x  SO2(微克每立方米)_x  \
# 0        上海市      上海市        35.990000       45.722400      24.510800
# 1        云南省      临沧市        24.324259       26.940926       7.508519
# 2        云南省      丽江市        19.836742       22.194831       6.295281
# 3        云南省      保山市        22.492000       25.107647       6.026118
# 4        云南省  大理白族自治州        27.516794       30.871145       7.742824
# ..       ...      ...              ...             ...            ...
# 365     黑龙江省      绥化市        37.726446       45.463313      19.644157
# 366     黑龙江省      鸡西市        17.274158       18.922277       4.961881
# 367     黑龙江省      鹤岗市         2.214118        2.684265       1.987206
# 368     黑龙江省      黑河市         2.390345        2.779530       1.392069
# 369     黑龙江省    齐齐哈尔市        11.140704       12.660000       4.567437
#
#      NO2(微克每立方米)_x  CO(毫克每立方米)_x  O3(微克每立方米)_x  U(m/s)_x  V(m/s)_x  ...  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 370 entries, 0 to 369
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   province         370 non-null    object
#  1   city             370 non-null    object
#  2   PM2.5(微克每立方米)_x  370 non-null    float64
#  3   PM10(微克每立方米)_x   370 non-null    float64
#  4   SO2(微克每立方米)_x    370 non-null    float64
#  5   NO2(微克每立方米)_x    370 non-null    float64
#  6   CO(毫克每立方米)_x     370 non-null    float64
#  7   O3(微克每立方米)_x     370 non-null    float64
#  8   U(m/s)_x         370 non-null    float64
#  9   V(m/s)_x         370 non-null    float64
#  10  TEMP(K)_x        370 non-null    float64
#  11  RH(%)_x          370 non-null    float64
#  12  PSFC(Pa)_x       370 non-null    float64
#  13  lat_x            370 non-null    float64
#  14  lon_x            370 non-null    float64
#  15  PM2.5(微克每立方米)_y  370 non-null    float64
# ...

# %%
df = pd.DataFrame({'Country':['China','China', 'India', 'India', 'America', 'Japan', 'China', 'India'], 
                    'Income':[10000, 10000, 5000, 5002, 40000, 50000, 8000, 5000],
                     'Age':[5000, 4321, 1234, 4010, 250, 250, 4500, 4321]})
df

# %%
df_agg = df.groupby('Country').agg(['min', 'mean', 'max'])
df_agg

# %%
# 显示所有列
pd.set_option('display.max_columns', None)
# 显示所有行
pd.set_option('display.max_rows', None)
